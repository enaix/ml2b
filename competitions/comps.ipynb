# %%
import pandas as pd

# %%
df = pd.read_csv("tasks/English.csv", index_col=0)

# %%
df
# Out:
#                                                                                       competition  \
# comp_name
# WiDS Datathon 2020                                                               widsdatathon2020
# IEOR 242 Spring 2020 HW 4                                                              ieor242hw4
# Explicit content detection                                             explicit-content-detection
# 109-1 NTUT Building Deep Learning Applications HW1                          109-1-ntut-dl-app-hw1
# UWaterloo STAT441/841 Data Challenge 1                                      stat441datachallenge1
# MADE HW-2                                                                               made-hw-2
# Financial Engineering Competition (1/3)                                                2020-10-29
# Financial Engineering Competition (2/3)                                                2020-11-05
# Financial Engineering Competition (3/3)                                                2020-11-20
# PRML-Data Contest-Nov 2020                                             prml-data-contest-nov-2020
# Actuarial loss prediction                                               actuarial-loss-estimation
# IPL 2020 Player Performance                                           ipl-2020-player-performance
# <She/Hacks> - Shaastra'21 and Wells Fargo                          shaastra-wells-fargo-hackathon
# ML2021Spring-hw1                                                                 ml2021spring-hw1
# 2021-기계학습                                                                            2021-ml-w1p1
# SYDE 522 (Winter 2021)                                   classification-with-non-deep-classifiers
# Tabular Playground Series - Jul 2021                           tabular-playground-series-jul-2021
# Tabular Playground Series - Aug 2021                           tabular-playground-series-aug-2021
# Classify Leaves                                                                   classify-leaves
# Google Brain - Ventilator Pressure Prediction                      ventilator-pressure-prediction
# Porto Seguro Data Challenge                                           porto-seguro-data-challenge
# NFL Health & Safety - Helmet Assignment                   nfl-health-and-safety-helmet-assignment
# Sartorius - Cell Instance Segmentation                       sartorius-cell-instance-segmentation
# Crime_Learn                                                                           crime-learn
# Binary Classification with a Tabular Stroke Pre...                         playground-series-s3e2
# Alfa University income prediction                               alfa-university-income-prediction
# Predicting Optimal Fertilizers                                             playground-series-s5e6
# Kaggle Community Olympiad - Fighting Maternal Risk                               mlolympiadbd2025
# March Machine Learning Mania 2025                               march-machine-learning-mania-2025
# Child Mind Institute — Problematic Internet Use     child-mind-institute-problematic-internet-use
# Amini GeoFM Decoding the Field Challenge                 amini-geofm-decoding-the-field-challenge
#
#                                                                                             data_card  \
# comp_name
# WiDS Datathon 2020                                  train.csv - the training data. Please view the...
# IEOR 242 Spring 2020 HW 4                           The training dataset (train.csv) contains a cs...
# Explicit content detection                          train.csv - the training set\nData fields:\nid...
# 109-1 NTUT Building Deep Learning Applications HW1  The training images are 28x28 gray images. The...
# UWaterloo STAT441/841 Data Challenge 1                                   train.csv - the training set
# MADE HW-2                                                              train.csv - the training set\n
# Financial Engineering Competition (1/3)                                train.csv - the training set\n
# Financial Engineering Competition (2/3)                                train.csv - the training set\n
# Financial Engineering Competition (3/3)             In this competition, you need to predict col_5...
# PRML-Data Contest-Nov 2020                          train.csv\ntrain.csv has rows corresponding to...
# Actuarial loss prediction                           This dataset includes realistic, synthetically...
# IPL 2020 Player Performance                         "train.csv" : File Containing various performa...
# <She/Hacks> - Shaastra'21 and Wells Fargo           The dataset provides you demographic data on t...
# ML2021Spring-hw1                                                             Training data: train.csv
# 2021-기계학습                                                                                         NaN
# SYDE 522 (Winter 2021)                              The data file train.csv contain feature vector...
# Tabular Playground Series - Jul 2021                In this competition you are predicting the val...
# Tabular Playground Series - Aug 2021                For this competition, you will be predicting a...
# Classify Leaves                                     This dataset contains categories, training ima...
# Google Brain - Ventilator Pressure Prediction       The ventilator data used in this competition w...
# Porto Seguro Data Challenge                         "In this competition, you will predict the pro...
# NFL Health & Safety - Helmet Assignment             In this competition, you are tasked with assig...
# Sartorius - Cell Instance Segmentation              In this competition we are segmenting neuronal...
# Crime_Learn                                         In this competition you will use the sample US...
# Binary Classification with a Tabular Stroke Pre...  Prediction Dataset. Feature distributions are ...
# Alfa University income prediction                                                                 NaN
# Predicting Optimal Fertilizers                      The dataset for this competition was generated...
# Kaggle Community Olympiad - Fighting Maternal Risk                                                NaN
# March Machine Learning Mania 2025                                                                 NaN
# Child Mind Institute — Problematic Internet Use                                                   NaN
# Amini GeoFM Decoding the Field Challenge                                                          NaN
#
#                                                                                      metric  \
# comp_name
# WiDS Datathon 2020                                                                      AUC
# IEOR 242 Spring 2020 HW 4                                                              RMSE
# Explicit content detection                                                           F_Beta
# 109-1 NTUT Building Deep Learning Applications HW1                   CategorizationAccuracy
# UWaterloo STAT441/841 Data Challenge 1                                                  AUC
# MADE HW-2                                                                       FScoreMicro
# Financial Engineering Competition (1/3)                                                RMSE
# Financial Engineering Competition (2/3)                                                RMSE
# Financial Engineering Competition (3/3)                                                RMSE
# PRML-Data Contest-Nov 2020                                                              map
# Actuarial loss prediction                                                              RMSE
# IPL 2020 Player Performance                                                            RMSE
# <She/Hacks> - Shaastra'21 and Wells Fargo                                              RMSE
# ML2021Spring-hw1                                                                       RMSE
# 2021-기계학습                                                            CategorizationAccuracy
# SYDE 522 (Winter 2021)                                               CategorizationAccuracy
# Tabular Playground Series - Jul 2021                                                MCRMSLE
# Tabular Playground Series - Aug 2021                                                   RMSE
# Classify Leaves                                                      CategorizationAccuracy
# Google Brain - Ventilator Pressure Prediction                                           MAE
# Porto Seguro Data Challenge                                                          F_Beta
# NFL Health & Safety - Helmet Assignment                             NFLHelmetIdentification
# Sartorius - Cell Instance Segmentation              IntersectionOverUnionObjectSegmentation
# Crime_Learn                                                                            RMSE
# Binary Classification with a Tabular Stroke Pre...                                      AUC
# Alfa University income prediction                                                      WMAE
# Predicting Optimal Fertilizers                                                        MAP@5
# Kaggle Community Olympiad - Fighting Maternal Risk                           Accuracy Score
# March Machine Learning Mania 2025                                               Brier score
# Child Mind Institute — Problematic Internet Use                    quadratic weighted kappa
# Amini GeoFM Decoding the Field Challenge                                            LogLoss
#
#                                                      comp_type    data_type  \
# comp_name
# WiDS Datathon 2020                                   Community      tabular
# IEOR 242 Spring 2020 HW 4                            Community      tabular
# Explicit content detection                           Community         text
# 109-1 NTUT Building Deep Learning Applications HW1   Community        image
# UWaterloo STAT441/841 Data Challenge 1               Community      tabular
# MADE HW-2                                            Community         text
# Financial Engineering Competition (1/3)              Community      tabular
# Financial Engineering Competition (2/3)              Community      tabular
# Financial Engineering Competition (3/3)              Community      tabular
# PRML-Data Contest-Nov 2020                           Community      tabular
# Actuarial loss prediction                            Community      tabular
# IPL 2020 Player Performance                          Community      tabular
# <She/Hacks> - Shaastra'21 and Wells Fargo            Community      tabular
# ML2021Spring-hw1                                     Community      tabular
# 2021-기계학습                                            Community      tabular
# SYDE 522 (Winter 2021)                               Community      tabular
# Tabular Playground Series - Jul 2021                Playground      tabular
# Tabular Playground Series - Aug 2021                Playground      tabular
# Classify Leaves                                      Community        image
# Google Brain - Ventilator Pressure Prediction         Research      tabular
# Porto Seguro Data Challenge                          Community      tabular
# NFL Health & Safety - Helmet Assignment               Featured      tabular
# Sartorius - Cell Instance Segmentation                Featured        image
# Crime_Learn                                          Community      tabular
# Binary Classification with a Tabular Stroke Pre...  Playground      tabular
# Alfa University income prediction                    Community      tabular
# Predicting Optimal Fertilizers                      Playground      tabular
# Kaggle Community Olympiad - Fighting Maternal Risk   Community      tabular
# March Machine Learning Mania 2025                     Featured      tabular
# Child Mind Institute — Problematic Internet Use       Featured  time series
# Amini GeoFM Decoding the Field Challenge                   NaN  time series
#
#                                                                                           description  \
# comp_name
# WiDS Datathon 2020                                  Develop a predictive model to forecast the lik...
# IEOR 242 Spring 2020 HW 4                           Develop a regression model to predict the dura...
# Explicit content detection                          The task aims to develop a content classifier ...
# 109-1 NTUT Building Deep Learning Applications HW1  Develop a classification model to predict the ...
# UWaterloo STAT441/841 Data Challenge 1              Develop a classification model to predict reve...
# MADE HW-2                                           Develop a text classification model to predict...
# Financial Engineering Competition (1/3)             Develop a prediction model to forecast the val...
# Financial Engineering Competition (2/3)             Develop a regression model to predict a numeri...
# Financial Engineering Competition (3/3)             A task was given to develop predictive models ...
# PRML-Data Contest-Nov 2020                          Develop a recommendation system to suggest tou...
# Actuarial loss prediction                           Develop a predictive model to estimate ultimat...
# IPL 2020 Player Performance                         Develop a model to predict total points scored...
# <She/Hacks> - Shaastra'21 and Wells Fargo           Develop a forecasting model to predict the num...
# ML2021Spring-hw1                                    Develop a predictive model to estimate the lik...
# 2021-기계학습                                           Develop a classifier to predict the diagnosis ...
# SYDE 522 (Winter 2021)                              Develop a classification model to predict labe...
# Tabular Playground Series - Jul 2021                Develop a model to predict levels of carbon mo...
# Tabular Playground Series - Aug 2021                Develop a predictive model to estimate custome...
# Classify Leaves                                     Develop a multi-label classification system to...
# Google Brain - Ventilator Pressure Prediction       Develop a model to predict ventilator pressure...
# Porto Seguro Data Challenge                         Develop a binary classification model to predi...
# NFL Health & Safety - Helmet Assignment             Develop a system to analyze player movements a...
# Sartorius - Cell Instance Segmentation              Develop a model for generating segmentation ma...
# Crime_Learn                                         Develop a predictive model to estimate the rat...
# Binary Classification with a Tabular Stroke Pre...  Develop a model to predict the risk of stroke ...
# Alfa University income prediction                   Develop a system to analyze client financial d...
# Predicting Optimal Fertilizers                      Develop a classification model to predict the ...
# Kaggle Community Olympiad - Fighting Maternal Risk  Develop a multi-class classification model to ...
# March Machine Learning Mania 2025                   Develop a predictive model to forecast the out...
# Child Mind Institute — Problematic Internet Use     Develop a predictive model to identify problem...
# Amini GeoFM Decoding the Field Challenge            Develop a crop classification model using geos...
#
#                                                                                 metric_type  \
# comp_name
# WiDS Datathon 2020                                                                      auc
# IEOR 242 Spring 2020 HW 4                                                               mse
# Explicit content detection                                                          f_score
# 109-1 NTUT Building Deep Learning Applications HW1                   categorizationaccuracy
# UWaterloo STAT441/841 Data Challenge 1                                                  auc
# MADE HW-2                                                                           f_score
# Financial Engineering Competition (1/3)                                                 mse
# Financial Engineering Competition (2/3)                                                 mse
# Financial Engineering Competition (3/3)                                                 mse
# PRML-Data Contest-Nov 2020                                                              map
# Actuarial loss prediction                                                               mse
# IPL 2020 Player Performance                                                             mse
# <She/Hacks> - Shaastra'21 and Wells Fargo                                               mse
# ML2021Spring-hw1                                                                        mse
# 2021-기계학습                                                            categorizationaccuracy
# SYDE 522 (Winter 2021)                                               categorizationaccuracy
# Tabular Playground Series - Jul 2021                                      percentage_errors
# Tabular Playground Series - Aug 2021                                                    mse
# Classify Leaves                                                      categorizationaccuracy
# Google Brain - Ventilator Pressure Prediction                                           mae
# Porto Seguro Data Challenge                                                         f_score
# NFL Health & Safety - Helmet Assignment                             nflhelmetidentification
# Sartorius - Cell Instance Segmentation              intersectionoverunionobjectsegmentation
# Crime_Learn                                                                             mse
# Binary Classification with a Tabular Stroke Pre...                                      auc
# Alfa University income prediction                                                       mae
# Predicting Optimal Fertilizers                                                          map
# Kaggle Community Olympiad - Fighting Maternal Risk                                 accuracy
# March Machine Learning Mania 2025                                                  accuracy
# Child Mind Institute — Problematic Internet Use                                 correlation
# Amini GeoFM Decoding the Field Challenge                                           log_loss
#
#                                                                                 domain  \
# comp_name
# WiDS Datathon 2020                                              healthcare and medical
# IEOR 242 Spring 2020 HW 4                                               urban planning
# Explicit content detection                                          content moderation
# 109-1 NTUT Building Deep Learning Applications HW1  hardwritten letters classification
# UWaterloo STAT441/841 Data Challenge 1                                       eCommerce
# MADE HW-2                                                                 social media
# Financial Engineering Competition (1/3)                          financial engineering
# Financial Engineering Competition (2/3)                                   social media
# Financial Engineering Competition (3/3)                          financial engineering
# PRML-Data Contest-Nov 2020                                                      sports
# Actuarial loss prediction                                        insurance and finance
# IPL 2020 Player Performance                                         sport competitions
# <She/Hacks> - Shaastra'21 and Wells Fargo                                    education
# ML2021Spring-hw1                                                     health and safety
# 2021-기계학습                                                       healthcare and medical
# SYDE 522 (Winter 2021)                                                    data science
# Tabular Playground Series - Jul 2021                             environmental science
# Tabular Playground Series - Aug 2021                                           finance
# Classify Leaves                                                          plant species
# Google Brain - Ventilator Pressure Prediction                   healthcare and medical
# Porto Seguro Data Challenge                                                    finance
# NFL Health & Safety - Helmet Assignment                              health-and-safety
# Sartorius - Cell Instance Segmentation                               biopharmaceutical
# Crime_Learn                                                           crime prediction
# Binary Classification with a Tabular Stroke Pre...              healthcare and medical
# Alfa University income prediction                                              finance
# Predicting Optimal Fertilizers                                   environmental science
# Kaggle Community Olympiad - Fighting Maternal Risk                   health and safety
# March Machine Learning Mania 2025                                               sports
# Child Mind Institute — Problematic Internet Use                      health and safety
# Amini GeoFM Decoding the Field Challenge                         environmental science
#
#                                                                                      competition_link  \
# comp_name
# WiDS Datathon 2020                                  https://www.kaggle.com/competitions/widsdatath...
# IEOR 242 Spring 2020 HW 4                              https://www.kaggle.com/competitions/ieor242hw4
# Explicit content detection                          https://www.kaggle.com/competitions/explicit-c...
# 109-1 NTUT Building Deep Learning Applications HW1  https://www.kaggle.com/competitions/109-1-ntut...
# UWaterloo STAT441/841 Data Challenge 1              https://www.kaggle.com/competitions/stat441dat...
# MADE HW-2                                               https://www.kaggle.com/competitions/made-hw-2
# Financial Engineering Competition (1/3)                https://www.kaggle.com/competitions/2020-10-29
# Financial Engineering Competition (2/3)                https://www.kaggle.com/competitions/2020-11-05
# Financial Engineering Competition (3/3)                https://www.kaggle.com/competitions/2020-11-20
# PRML-Data Contest-Nov 2020                          https://www.kaggle.com/competitions/prml-data-...
# Actuarial loss prediction                           https://www.kaggle.com/competitions/actuarial-...
# IPL 2020 Player Performance                         https://www.kaggle.com/competitions/ipl-2020-p...
# <She/Hacks> - Shaastra'21 and Wells Fargo           https://www.kaggle.com/competitions/shaastra-w...
# ML2021Spring-hw1                                    https://www.kaggle.com/competitions/ml2021spri...
# 2021-기계학습                                            https://www.kaggle.com/competitions/2021-ml-w1p1
# SYDE 522 (Winter 2021)                              https://www.kaggle.com/competitions/classifica...
# Tabular Playground Series - Jul 2021                https://www.kaggle.com/competitions/tabular-pl...
# Tabular Playground Series - Aug 2021                https://www.kaggle.com/competitions/tabular-pl...
# Classify Leaves                                     https://www.kaggle.com/competitions/classify-l...
# Google Brain - Ventilator Pressure Prediction       https://www.kaggle.com/competitions/ventilator...
# Porto Seguro Data Challenge                         https://www.kaggle.com/competitions/porto-segu...
# NFL Health & Safety - Helmet Assignment             https://www.kaggle.com/competitions/nfl-health...
# Sartorius - Cell Instance Segmentation              https://www.kaggle.com/competitions/sartorius-...
# Crime_Learn                                           https://www.kaggle.com/competitions/crime-learn
# Binary Classification with a Tabular Stroke Pre...  https://www.kaggle.com/competitions/playground...
# Alfa University income prediction                   https://www.kaggle.com/competitions/alfa-unive...
# Predicting Optimal Fertilizers                      https://www.kaggle.com/competitions/playground...
# Kaggle Community Olympiad - Fighting Maternal Risk  https://www.kaggle.com/competitions/mlolympiad...
# March Machine Learning Mania 2025                   https://www.kaggle.com/competitions/march-mach...
# Child Mind Institute — Problematic Internet Use     https://www.kaggle.com/competitions/child-mind...
# Amini GeoFM Decoding the Field Challenge            https://zindi.africa/competitions/amini-geofm-...
#
#                                                    is_grading_done  \
# comp_name
# WiDS Datathon 2020                                             yes
# IEOR 242 Spring 2020 HW 4                                      yes
# Explicit content detection                                     yes
# 109-1 NTUT Building Deep Learning Applications HW1     in progress
# UWaterloo STAT441/841 Data Challenge 1                         yes
# MADE HW-2                                                       no
# Financial Engineering Competition (1/3)                        yes
# Financial Engineering Competition (2/3)                         no
# Financial Engineering Competition (3/3)                         no
# PRML-Data Contest-Nov 2020                                      no
# Actuarial loss prediction                                      yes
# IPL 2020 Player Performance                                     no
# <She/Hacks> - Shaastra'21 and Wells Fargo                      yes
# ML2021Spring-hw1                                                no
# 2021-기계학습                                                      yes
# SYDE 522 (Winter 2021)                                         yes
# Tabular Playground Series - Jul 2021                            no
# Tabular Playground Series - Aug 2021                           yes
# Classify Leaves                                        in progress
# Google Brain - Ventilator Pressure Prediction                  yes
# Porto Seguro Data Challenge                                    yes
# NFL Health & Safety - Helmet Assignment                         no
# Sartorius - Cell Instance Segmentation                          no
# Crime_Learn                                                    yes
# Binary Classification with a Tabular Stroke Pre...             yes
# Alfa University income prediction                               no
# Predicting Optimal Fertilizers                                 NEW
# Kaggle Community Olympiad - Fighting Maternal Risk             NEW
# March Machine Learning Mania 2025                              NEW
# Child Mind Institute — Problematic Internet Use                NEW
# Amini GeoFM Decoding the Field Challenge                       NEW
#
#                                                                         competition-id
# comp_name
# WiDS Datathon 2020                                                  wids-datathon-2020
# IEOR 242 Spring 2020 HW 4                                            ieor-242-nyc-taxi
# Explicit content detection                                  explicit-content-detection
# 109-1 NTUT Building Deep Learning Applications HW1                                 NaN
# UWaterloo STAT441/841 Data Challenge 1                       uwaterloo-stat441-jewelry
# MADE HW-2                                                                          NaN
# Financial Engineering Competition (1/3)                        financial-engineering-1
# Financial Engineering Competition (2/3)                                            NaN
# Financial Engineering Competition (3/3)                                            NaN
# PRML-Data Contest-Nov 2020                                                         NaN
# Actuarial loss prediction                                    actuarial-loss-prediction
# IPL 2020 Player Performance                                                        NaN
# <She/Hacks> - Shaastra'21 and Wells Fargo                               she-hacks-2021
# ML2021Spring-hw1                                                                   NaN
# 2021-기계학습                                                        ai-cancer-predictions
# SYDE 522 (Winter 2021)                                            syde-522-winter-2021
# Tabular Playground Series - Jul 2021                                               NaN
# Tabular Playground Series - Aug 2021                tabular-playground-series-aug-2021
# Classify Leaves                                                                    NaN
# Google Brain - Ventilator Pressure Prediction                  google-brain-ventilator
# Porto Seguro Data Challenge                                     porto-seguro-challenge
# NFL Health & Safety - Helmet Assignment                                            NaN
# Sartorius - Cell Instance Segmentation                                             NaN
# Crime_Learn                                                                crime-learn
# Binary Classification with a Tabular Stroke Pre...              stroke-prediction-s3e2
# Alfa University income prediction                                                  NaN
# Predicting Optimal Fertilizers                                                     NaN
# Kaggle Community Olympiad - Fighting Maternal Risk                                 NaN
# March Machine Learning Mania 2025                                                  NaN
# Child Mind Institute — Problematic Internet Use                                    NaN
# Amini GeoFM Decoding the Field Challenge                                           NaN

# %%
competition_map = {
    "widsdatathon2020": "wids-datathon-2020",
    "ieor242hw4": "ieor-242-nyc-taxi",
    "explicit-content-detection": "explicit-content-detection",
    "stat441datachallenge1": "uwaterloo-stat441-jewelry",
    "2020-10-29": "financial-engineering-1",
    "actuarial-loss-estimation": "actuarial-loss-prediction",
    "shaastra-wells-fargo-hackathon": "she-hacks-2021",
    "2021-ml-w1p1": "ai-cancer-predictions",
    "classification-with-non-deep-classifiers": "syde-522-winter-2021",
    "ventilator-pressure-prediction": "google-brain-ventilator",
    "porto-seguro-data-challenge": "porto-seguro-challenge",
    "crime-learn": "crime-learn",
    "playground-series-s3e2": "stroke-prediction-s3e2",
    "tabular-playground-series-aug-2021": "tabular-playground-series-aug-2021"
}

# %%
df['competition-id'] = df['competition'].map(competition_map)
# Out:
# comp_name
# WiDS Datathon 2020                                                        wids-datathon-2020
# IEOR 242 Spring 2020 HW 4                                                  ieor-242-nyc-taxi
# Explicit content detection                                        explicit-content-detection
# 109-1 NTUT Building Deep Learning Applications HW1                                       NaN
# UWaterloo STAT441/841 Data Challenge 1                             uwaterloo-stat441-jewelry
# MADE HW-2                                                                                NaN
# Financial Engineering Competition (1/3)                              financial-engineering-1
# Financial Engineering Competition (2/3)                                                  NaN
# Financial Engineering Competition (3/3)                                                  NaN
# PRML-Data Contest-Nov 2020                                                               NaN
# Actuarial loss prediction                                          actuarial-loss-prediction
# IPL 2020 Player Performance                                                              NaN
# <She/Hacks> - Shaastra'21 and Wells Fargo                                     she-hacks-2021
# ML2021Spring-hw1                                                                         NaN
# 2021-기계학습                                                              ai-cancer-predictions
# SYDE 522 (Winter 2021)                                                  syde-522-winter-2021
# Tabular Playground Series - Jul 2021                                                     NaN
# Tabular Playground Series - Aug 2021                                                     NaN
# Classify Leaves                                                                          NaN
# Google Brain - Ventilator Pressure Prediction                        google-brain-ventilator
# Porto Seguro Data Challenge                                           porto-seguro-challenge
# NFL Health & Safety - Helmet Assignment                                                  NaN
# Sartorius - Cell Instance Segmentation                                                   NaN
# Crime_Learn                                                                      crime-learn
# Binary Classification with a Tabular Stroke Prediction Dataset        stroke-prediction-s3e2
# Alfa University income prediction                                                        NaN
# Predicting Optimal Fertilizers                                                           NaN
# Kaggle Community Olympiad - Fighting Maternal Risk                                       NaN
# March Machine Learning Mania 2025                                                        NaN
# Child Mind Institute — Problematic Internet Use                                          NaN
# Amini GeoFM Decoding the Field Challenge                                                 NaN
# Name: competition, dtype: object

# %%
comp_ids = ["wids-datathon-2020", 
            "ieor-242-nyc-taxi", 
            "explicit-content-detection", 
            "109-1-ntut-dl-app", #need add
            "uwaterloo-stat441-jewelry", 
            "made-hw-2", #add
            "financial-engineering-1",
            "financial-engineering-2", #add
            "financial-engineering-3", #add
            "prml-data-contest-nov-2020", #add
            "actuarial-loss-prediction",
            "ipl-2020-player-performance", #add
            "she-hacks-2021",
            "ml2021spring-hw1", #add
            "ai-cancer-predictions",
            "syde-522-winter-2021",
            "tabular-playground-jul-2021",#add???
            "tabular-playground-aug-2021",#add???
            "classify-leaves", #add
            "google-brain-ventilator",
            "porto-seguro-challenge",
            "nfl-health-and-safety-helmet-assignment", #add
            "sartorius-cell-instance-segmentation", #add
            "crime-learn",
            "stroke-prediction-s3e2",
            "alfa-university-income-prediction"#add
            ]

# %%
import pandas as pd
from pathlib import Path

def add_competition_id_to_all(directory_path, competition_map):
    folder = Path(directory_path)
    
    for csv_file in folder.glob("*.csv"):
        try:
            df = pd.read_csv(csv_file, sep=None, engine='python')
            df['competition-id'] = df['competition'].map(competition_map)
            # Добавляем competition-id как первый столбец
            
            df.to_csv(csv_file, index=False, encoding='utf-8')
            print(f"✅ Добавлен competition-id в {csv_file.name}")
            
        except Exception as e:
            print(f"❌ Ошибка с {csv_file.name}: {e}")

# Использование

add_competition_id_to_all("tasks", competition_map)
# Out:
# ✅ Добавлен competition-id в Chinese.csv
# ✅ Добавлен competition-id в Italian.csv
# ✅ Добавлен competition-id в English.csv
# ✅ Добавлен competition-id в Spanish.csv
# ✅ Добавлен competition-id в Kazakh.csv
# ✅ Добавлен competition-id в Polish.csv
# ✅ Добавлен competition-id в Turkish.csv
# ✅ Добавлен competition-id в Japanese.csv
# ✅ Добавлен competition-id в Romanian.csv
# ✅ Добавлен competition-id в Arab.csv
# ✅ Добавлен competition-id в Belarus.csv
